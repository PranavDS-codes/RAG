# %%
import numpy as np
np.random.seed(42)

# %%
nums = [x for x in range(0, 100_000)]
choice = np.random.choice(nums, size=10)
choice
# Out:
# array([15795,   860, 76820, 54886,  6265, 82386, 37194, 87498, 44131,
#        60263])
