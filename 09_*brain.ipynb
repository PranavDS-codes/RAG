# %%
from graph import build_graph, ask_brain 

# --- BUILD THE GRAPH ---
# Compile
app = build_graph()
print("✅ Agent Compiled and Ready.")
app
# Out:
# ⚙️  Injecting High-Fidelity Probes...
# 📂 Loading Resources...
# 🚀 Omni-Retriever Ready.
# 🚀 Probes Active.
# ✅ Agent Compiled and Ready.

# %%
ask_brain("What driver did Tiger Woods use this specific model at the 2025 PNC Championship?", app)
# Out:
# 📼 Deep Trace started: trace_20260120_170753
#
# ❓ QUERY: What driver did Tiger Woods use this specific model at the 2025 PNC Championship?
# ...
#
# 📚 [LIBRARIAN] Executing Traced Retrieval...
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 🕵️‍♂️ [AUDITOR] Auditing Evidence & Freshness...
#    ❌ Gaps detected: ['Tiger Woods driver model used at the 2025 PNC Championship', 'Equipment details for the 2025 PNC Championship (golf clubs used by Tiger Woods)']
#    ✂️ Pruning Internal Knowledge (Keeping top 1 of 5)...
# 🌐 [WEB SCOUT] Tracing Web Search for 2 topics...
#    🔎 Scouting External Cortex for: 'Tiger Woods driver model used at the 2025 PNC Championship'...
#    👀 Retrieved 5 high-fidelity sources...
#    🧠 Curating (web_scout)...
#    💾 Knowledge Artifact Saved to ./models/pending_knowledge.json
#    🔎 Scouting External Cortex for: 'Equipment details for the 2025 PNC Championship (golf clubs used by Tiger Woods)'...
#    👀 Retrieved 5 high-fidelity sources...
# ...

# %%
ask_brain("What are the precise loft sleeve adjustments (in degrees) for the TaylorMade Qi10 LS driver, \
and did Tiger Woods use this specific model at the 2025 PNC Championship?", app)
# Out:
# 📼 Deep Trace started: trace_20260120_170152
#
# ❓ QUERY: What are the precise loft sleeve adjustments (in degrees) for the TaylorMade Qi10 LS driver, and did Tiger Woods use this specific model at the 2025 PNC Championship?
# ...
#
# 📚 [LIBRARIAN] Executing Traced Retrieval...
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 🕵️‍♂️ [AUDITOR] Auditing Evidence & Freshness...
#    ❌ Gaps detected: ['Precise loft sleeve adjustment degrees for the TaylorMade Qi10 LS driver', 'Whether Tiger Woods used the TaylorMade Qi10 LS driver at the 2025 PNC Championship']
#    ✂️ Pruning Internal Knowledge (Keeping top 1 of 10)...
# 🌐 [WEB SCOUT] Tracing Web Search for 2 topics...
#    🔎 Scouting External Cortex for: 'Precise loft sleeve adjustment degrees for the TaylorMade Qi10 LS driver'...
#    👀 Retrieved 5 high-fidelity sources...
#    🧠 Curating (web_scout)...
#    💾 Knowledge Artifact Saved to ./models/pending_knowledge.json
# ...
